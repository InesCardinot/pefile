# %% [markdown]
# <a href="https://colab.research.google.com/github/InesCardinot/pefile/blob/master/Usandopefile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Desafio CyberLabs
# ---
# **Crie um código em Python que receba o path de um executável via parâmetro, parseie o arquivo executável para exibir todas as funções utilizadas. Para fazer essa tarefa é necessário utilizar uma lib python de parseamento de arquivos PE.**
#
# *Essa é uma vaga de estágio, portanto, pesquise, aprenda e use seus conhecimentos para tentar resolver o desafio. Lembre-se de adicionar comentários ao seu código.*

# %% [markdown]
# * Como esse é o nosso primeiro contato mais técnico e o desafio é para conquistar uma vaga, detalharei o máximo possível como desenvolvi a tarefa.
# ---

# %% [markdown]
# Para instalar a biblioteca que manipula arquivos executáveis, utilizei o comando ‘pip’:
# #####*(lib python de parseamento de arquivos PE)*

# %%
pip install pefile
# Out:
# ...
#      |████████████████████████████████| 66 kB 2.3 MB/s
# ...
#   Created wheel for pefile: filename=pefile-2021.5.24-py3-none-any.whl size=62591 sha256=d03179132aaaf5a2cbcf6bd4503361f6f902e318b0396d094f07e6097e3c1a97
#   Stored in directory: /root/.cache/pip/wheels/85/ea/e0/6b00cf7797a191cc56bd6607ff5d5a89f4da0371aa3a3a95c5
# Successfully built pefile
# ...

# %% [markdown]
# Para importar a biblioteca pefile:

# %%
import pefile

# %% [markdown]
# Usando o comando que recebe o caminho do arquivo .exe
# #####*(receba o path de um executável)*

# %%
pe = pefile.PE("/content/setup_johnny_castaway.exe")

# %% [markdown]
# printando um executável
# #####*(via parâmetro para exibir todas as funções utilizadas)*

# %%
print(pe)
# Out:
# ----------DOS_HEADER----------
#
# [IMAGE_DOS_HEADER]
# 0x0        0x0   e_magic:                       0x5A4D
# 0x2        0x2   e_cblp:                        0x50
# 0x4        0x4   e_cp:                          0x2
# 0x6        0x6   e_crlc:                        0x0
# 0x8        0x8   e_cparhdr:                     0x4
# 0xA        0xA   e_minalloc:                    0xF
# 0xC        0xC   e_maxalloc:                    0xFFFF
# 0xE        0xE   e_ss:                          0x0
# 0x10       0x10  e_sp:                          0xB8
# 0x12       0x12  e_csum:                        0x0
# 0x14       0x14  e_ip:                          0x0
# 0x16       0x16  e_cs:                          0x0
# 0x18       0x18  e_lfarlc:                      0x40
# 0x1A       0x1A  e_ovno:                        0x1A
# 0x1C       0x1C  e_res:
# 0x24       0x24  e_oemid:                       0x0
# 0x26       0x26  e_oeminfo:                     0x0
# 0x28       0x28  e_res2:
# ...
